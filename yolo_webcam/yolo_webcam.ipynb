# %%
from ultralytics import YOLO
import cv2
import cvzone
import math

# %%
# # # for webcam
# cap = cv2.VideoCapture(0)
# cap.set(3,1280)
# cap.set(4,720)

# %%
# # for videos
cap = cv2.VideoCapture('../videos/cars.mp4')

# %%
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
print(f"Resolution: {width}x{height}")
# Out:
# Resolution: 3840.0x2160.0

# %%
import torch
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
model = YOLO('../yolo_weights/yolov8n.pt')
model.to(device)
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): Upsample(scale_factor=2.0, mode='nearest')
#       (11): Concat()
#       (12): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (13): Upsample(scale_factor=2.0, mode='nearest')
#       (14): Concat()
#       (15): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (16): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (17): Concat()
#       (18): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (19): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (20): Concat()
#       (21): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (22): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %%
class_names = ["person", "bicycle", "car", "motorcycle", "airplane", "bus", "train", "truck", 
               "boat", "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", 
               "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", 
               "giraffe", "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", 
               "skis", "snowboard", "sports ball", "kite", "baseball bat", "baseball glove", 
               "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup", "fork", 
               "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli", 
               "carrot", "hot dog", "pizza", "donut", "cake", "chair", "couch", "potted plant", 
               "bed", "dining table", "toilet", "tv", "laptop", "mouse", "remote", "keyboard", 
               "cell phone", "microwave", "oven", "toaster", "sink", "refrigerator", "book", 
               "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush"]

# %%
mask=cv2.imread('../videos/mask.png')

# %%
from sort import *
tracker =Sort(max_age=20,min_hits=3,iou_threshold=0.3)

# %%
import numpy as np
limits = [2388,1014,3696,729]
total_count=[]

# %%
while True:
    success, img = cap.read()
    img_region=cv2.bitwise_and(img,mask)
    results = model(img_region, stream=True)

    detection=np.empty((0,5))

    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            w, h = x2 - x1, y2 - y1
            

            conf = math.ceil((box.conf[0] * 100)) / 100 
            cls_id = int(box.cls[0]) 
            
            cls_name = class_names[cls_id] if cls_id < len(class_names) else "Unknown"
            
            current_class=class_names[cls_id]
            if current_class=='car' and conf>0.5:
                cvzone.cornerRect(img, (x1, y1, w, h),l=5,rt=4)
                # cvzone.putTextRect(img, f'{cls_name} {conf}', (max(0, x1), max(35, y1)),scale=1.7,thickness=1)
                current_array=np.array([x1,y1,x2,y2,conf])
                detection=np.vstack((detection,current_array))

    result_tracker=tracker.update(detection)
    cv2.line(img,(limits[0],limits[1]),(limits[2],limits[3]),(0,255,255),5)

    for result in result_tracker:
        x1,y1,x2,y2,ID=result
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
        w, h = x2 - x1, y2 - y1
        print(result)
        cvzone.cornerRect(img, (x1, y1, w, h),l=5,rt=1,colorR=(255,0,0))
        cvzone.putTextRect(img, f'{int(ID)}', (max(0, x1), max(35, y1)),scale=1.7,thickness=1)

        cx,cy=x1+w//2,y1+h//2
        cv2.circle(img,(cx,cy),5,(255,0,255),cv2.FILLED)

        if limits[0]<cx<limits[2]:
            if total_count.count(ID)==0:
                total_count.append(ID)
                cv2.line(img,(limits[0],limits[1]),(limits[2],limits[3]),(0,255,0),5)
                
    cvzone.putTextRect(img, f'count: {len(total_count)}', (50, 50))

    cv2.imshow("Image", img)
    # cv2.imshow("Image", img_region)
    cv2.waitKey(1)
# Out:
# WARNING ⚠️ NMS time limit 2.050s exceeded
# 0: 384x640 2 cars, 1 truck, 274.0ms
# Speed: 76.6ms preprocess, 274.0ms inference, 5379.6ms postprocess per image at shape (1, 3, 384, 640)
# [       2455         711        2947        1056           2]
# [       3429         908        3838        1304           1]
#
# 0: 384x640 2 cars, 1 truck, 35.7ms
# Speed: 5.6ms preprocess, 35.7ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2493.6      719.74      2994.4      1078.3           2]
# [     3476.8      921.78      3845.2      1308.2           1]
#
# 0: 384x640 2 cars, 1 truck, 18.0ms
# Speed: 2.5ms preprocess, 18.0ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2536.4      724.31      3032.9        1084           2]
# [     3522.1      943.27      3851.1      1321.7           1]
#
# WARNING ⚠️ NMS time limit 2.050s exceeded
# 0: 384x640 3 cars, 1 truck, 17.6ms
# Speed: 2.6ms preprocess, 17.6ms inference, 2210.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2587.9      734.22      3090.3        1098           2]
# [     3591.6      970.89      3860.5      1326.1           1]
#
# 0: 384x640 3 cars, 1 truck, 19.3ms
# Speed: 2.3ms preprocess, 19.3ms inference, 43.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2631.2      741.82      3133.4      1106.1           2]
# [     3651.4      992.27      3864.2      1323.4           1]
#
# 0: 384x640 3 cars, 1 truck, 18.1ms
# Speed: 2.2ms preprocess, 18.1ms inference, 41.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2673.3      751.86      3176.3      1118.5           2]
# [     3713.6      1035.2      3864.3      1319.6           1]
#
# 0: 384x640 3 cars, 1 truck, 15.1ms
# Speed: 2.5ms preprocess, 15.1ms inference, 40.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2386.5      654.33      2616.6      972.14           3]
# [     2724.8      767.79      3230.9      1134.9           2]
#
# 0: 384x640 3 cars, 1 truck, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2394.2      719.11      2651.9      1002.3           3]
# [     2766.1       777.9      3278.9      1149.8           2]
#
# 0: 384x640 2 cars, 1 truck, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 45.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2393.8      689.72      2693.8      1006.4           3]
# [     2808.7      786.84      3325.2      1160.5           2]
#
# 0: 384x640 2 cars, 1 truck, 15.4ms
# Speed: 2.2ms preprocess, 15.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2402.5      682.23      2744.7      1017.5           3]
# [     2861.2      798.67      3382.5      1177.3           2]
#
# 0: 384x640 2 cars, 1 truck, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 39.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2401.5      684.37      2785.5      1031.6           3]
# [     2903.6      805.91      3431.3      1189.7           2]
#
# 0: 384x640 2 cars, 1 truck, 17.0ms
# Speed: 2.2ms preprocess, 17.0ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2401.4      691.94      2824.5      1042.6           3]
# [     2948.6      813.41      3482.5      1203.4           2]
#
# 0: 384x640 2 cars, 1 truck, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 52.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2421.2      702.48      2876.6      1055.4           3]
# [     3000.7      824.77      3539.8      1222.3           2]
#
# 0: 384x640 2 cars, 1 truck, 17.8ms
# Speed: 2.3ms preprocess, 17.8ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2450.1      714.38      2926.2      1069.1           3]
# [     3045.4      839.18      3588.3      1241.6           2]
#
# 0: 384x640 3 cars, 1 truck, 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 40.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2483.9      721.51        2975      1076.3           3]
# [     3090.6      849.61      3636.7      1253.5           2]
#
# 0: 384x640 3 cars, 1 truck, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2527.7       730.3      3029.2      1084.3           3]
# [     3143.4      865.85      3691.5      1267.9           2]
#
# 0: 384x640 4 cars, 1 truck, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 54.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2567.7       741.2      3078.1      1093.1           3]
# [     3191.7       882.2      3742.2      1281.3           2]
#
# 0: 384x640 3 cars, 1 truck, 17.4ms
# Speed: 2.3ms preprocess, 17.4ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2607.2      752.96      3123.2      1105.4           3]
# [     3236.5      894.12      3789.3      1292.9           2]
#
# 0: 384x640 3 cars, 1 truck, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2389.1      608.92      2663.7      967.69           4]
# [       2656      765.16      3176.6      1117.5           3]
# [     3289.6      904.78      3841.7        1306           2]
#
# 0: 384x640 3 cars, 1 truck, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2393.7       611.9      2701.6      984.35           4]
# [     2700.6      774.84      3225.9      1128.9           3]
# [     3331.9      913.55      3868.2      1315.2           2]
#
# 0: 384x640 3 cars, 1 truck, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2396.5      617.32      2741.6      997.31           4]
# [     2741.9      784.95      3270.9      1139.4           3]
# [     3369.9      923.66      3881.8      1326.1           2]
#
# 0: 384x640 3 cars, 1 truck, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# [       2404      626.98        2787      1011.2           4]
# [     2788.4      798.71      3320.8      1155.7           3]
# [     3416.8      937.76      3892.6      1340.8           2]
#
# 0: 384x640 3 cars, 1 truck, 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2402.9      639.74      2826.3        1027           4]
# [     2832.3      806.92      3368.5      1166.2           3]
# [     3460.6      952.43      3897.1      1354.5           2]
#
# 0: 384x640 3 cars, 1 truck, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 43.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2415.1      649.23      2871.6      1037.4           4]
# [     2875.5      816.29      3413.2      1178.3           3]
# [     3504.2      964.85        3899      1366.4           2]
#
# 0: 384x640 3 cars, 1 truck, 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# [       2455      662.39      2929.5        1049           4]
# [       2925      830.22      3465.6      1196.1           3]
# [     3558.7      984.86      3903.5      1383.6           2]
#
# 0: 384x640 3 cars, 1 truck, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2493.1      671.43      2979.2      1056.5           4]
# [     2970.4      842.88      3514.5      1215.1           3]
# [     3609.2      997.33      3904.2      1394.9           2]
#
# 0: 384x640 3 cars, 1 truck, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2530.8      682.76      3025.5      1066.6           4]
# [       3012      854.15      3560.2      1230.8           3]
# [     3654.4      1002.5      3903.3      1408.3           2]
#
# 0: 384x640 3 cars, 1 truck, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2577.2      693.52      3077.3      1075.1           4]
# [     3063.5      867.38        3615      1247.4           3]
#
# 0: 384x640 3 cars, 1 truck, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 40.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2620.6      704.48      3125.3      1086.6           4]
# [     3109.7      880.48      3662.5      1259.3           3]
#
# 0: 384x640 3 cars, 1 truck, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2659.7      711.37      3169.8      1095.4           4]
# [     3154.2      892.75      3708.3      1270.8           3]
#
# 0: 384x640 3 cars, 1 truck, 17.0ms
# Speed: 2.3ms preprocess, 17.0ms inference, 46.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2707.3      723.77        3223      1110.6           4]
# [     3205.5      903.82      3761.6      1284.3           3]
#
# 0: 384x640 3 cars, 1 truck, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2749.2      735.52      3268.5      1122.4           4]
# [       3252      913.12      3811.5      1297.3           3]
#
# 0: 384x640 3 cars, 1 truck, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2425.3      469.49      2700.1      782.15           5]
# [       2790      747.64      3312.1      1134.3           4]
# [     3294.2      923.13      3852.5        1310           3]
#
# 0: 384x640 3 cars, 1 truck, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2428.7      471.31        2738      795.35           5]
# [     2840.5      759.26      3366.3      1145.5           4]
# [     3335.9      935.67      3876.8      1324.3           3]
#
# 0: 384x640 3 cars, 1 truck, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2435.3      474.31      2775.6      805.03           5]
# [     2884.2      770.42      3412.7      1156.7           4]
# [     3373.6      948.59      3888.7      1338.4           3]
#
# 0: 384x640 3 cars, 1 truck, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 46.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2437.4      477.12      2812.9       812.6           5]
# [     2925.1      780.56        3459      1166.1           4]
# [     3412.7      961.73      3895.8      1353.1           3]
#
# 0: 384x640 3 cars, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2455.4      481.84      2861.8      820.93           5]
# [     2975.1      792.43      3513.9      1179.9           4]
# [     3457.5      976.27      3901.7      1369.2           3]
#
# 0: 384x640 3 cars, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2483.7      487.81      2908.5       827.5           5]
# [     3018.4      802.58        3562      1191.9           4]
# [     3503.1      991.66      3904.9      1383.6           3]
#
# 0: 384x640 3 cars, 17.0ms
# Speed: 2.8ms preprocess, 17.0ms inference, 45.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2514.4      495.78      2952.7      833.22           5]
# [     3062.5      813.04      3608.8      1205.5           4]
# [     3547.5        1010      3905.8      1404.5           3]
#
# 0: 384x640 3 cars, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# [       2559      505.86      3002.9      839.89           5]
# [     3114.1      826.31      3664.6      1223.5           4]
# [     3600.3        1025        3909      1417.3           3]
#
# 0: 384x640 3 cars, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2597.2      512.25      3049.1      846.67           5]
# [     3158.5       838.1      3711.8      1238.6           4]
# [     3648.5      1030.7      3909.1      1431.7           3]
#
# 0: 384x640 2 cars, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 58.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2632.3      516.98      3089.8      851.74           5]
# [     3203.3      851.08      3757.7        1252           4]
#
# 0: 384x640 2 cars, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 43.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2676.6      524.84      3138.5      859.73           5]
# [     3255.1      865.69      3812.6      1266.3           4]
#
# 0: 384x640 2 cars, 17.1ms
# Speed: 2.3ms preprocess, 17.1ms inference, 42.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2717.1      529.81      3181.5       865.6           5]
# [     3298.3      877.18      3852.7      1276.7           4]
#
# 0: 384x640 2 cars, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2755.4       534.1      3222.3      870.25           5]
# [     3334.3      888.61      3873.5      1287.9           4]
#
# 0: 384x640 2 cars, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2800.9      539.94        3270      877.89           5]
# [     3375.3      900.53      3887.2      1301.4           4]
#
# 0: 384x640 3 cars, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2841.7      547.22      3311.9      886.49           5]
# [     3417.4      909.99      3895.7      1313.2           4]
#
# 0: 384x640 3 cars, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2881.4      556.59      3352.8      893.88           5]
# [     3456.7      921.18      3899.1      1326.3           4]
#
# 0: 384x640 3 cars, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2928.1      565.83      3400.9      903.02           5]
# [     3505.6      937.69      3904.3      1344.4           4]
#
# 0: 384x640 3 cars, 17.1ms
# Speed: 2.4ms preprocess, 17.1ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2391.7       622.1      2639.9      996.97           6]
# [     2970.1      574.52      3444.8      912.67           5]
# [     3550.5      950.85      3904.9      1359.9           4]
#
# 0: 384x640 3 cars, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# [       2394       622.4      2677.2      1007.1           6]
# [     3009.6      580.17        3487      920.06           5]
# [     3594.2      963.96      3904.1      1373.9           4]
#
# 0: 384x640 3 cars, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2398.7      629.12      2722.1      1022.2           6]
# [     3056.6      586.81      3536.3      928.38           5]
# [     3643.3       975.6      3905.7      1388.7           4]
#
# 0: 384x640 3 cars, 17.4ms
# Speed: 2.2ms preprocess, 17.4ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2399.4      640.69      2762.4      1035.7           6]
# [       3098       592.6      3579.9      936.98           5]
# [     3690.2      1005.4      3905.1      1410.5           4]
#
# 0: 384x640 2 cars, 16.1ms
# Speed: 2.5ms preprocess, 16.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2399.7      651.59      2800.8      1049.5           6]
# [     3135.7       599.2      3618.9      945.19           5]
#
# 0: 384x640 2 cars, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2411.8      661.28      2850.8      1060.9           6]
# [     3184.6       608.6      3670.9      955.99           5]
#
# 0: 384x640 2 cars, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2446.8      670.65      2903.1      1068.6           6]
# [     3223.7      615.33        3712         963           5]
#
# 0: 384x640 2 cars, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2483.4       680.9      2952.6      1077.3           6]
# [       3264      621.02      3752.3      969.89           5]
#
# 0: 384x640 2 cars, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2528.8      695.39      3006.7      1089.1           6]
# [     3310.5      628.44      3800.4      979.85           5]
#
# 0: 384x640 2 cars, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2571.4      703.53      3055.4      1096.7           6]
# [     3352.6      634.93      3843.2      988.63           5]
#
# 0: 384x640 2 cars, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2609.2      712.98      3100.6      1107.6           6]
# [     3382.7      640.78      3864.7      996.59           5]
#
# 0: 384x640 3 cars, 16.3ms
# Speed: 2.2ms preprocess, 16.3ms inference, 46.4ms postprocess per image at shape (1, 3, 384, 640)
# [       2656      721.96      3152.6      1116.8           6]
# [     3420.1      649.86      3879.6        1006           5]
#
# 0: 384x640 3 cars, 15.2ms
# Speed: 2.2ms preprocess, 15.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2699.6      734.45      3199.8      1130.2           6]
# [     3455.6      660.62      3887.4      1015.5           5]
#
# 0: 384x640 3 cars, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2741.5       745.7        3245      1141.2           6]
# [     3489.6       669.6      3890.9      1024.2           5]
#
# 0: 384x640 3 cars, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2789.9      760.48      3296.5      1155.8           6]
# [     3532.7         679      3895.6        1034           5]
#
# 0: 384x640 3 cars, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 39.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2426.6      473.19      2692.5      791.53           7]
# [     2833.4         771      3343.3      1166.9           6]
# [     3572.7      683.81      3897.6      1039.9           5]
#
# 0: 384x640 3 cars, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2430.2      473.43        2729      801.22           7]
# [     2876.1      779.67      3388.6      1177.4           6]
# [     3610.1      692.18      3896.8      1048.8           5]
#
# 0: 384x640 3 cars, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2437.6      478.13      2771.9      811.88           7]
# [     2926.4       792.1      3443.7      1193.2           6]
# [     3655.1      704.96      3898.7      1059.1           5]
#
# 0: 384x640 1 person, 2 cars, 16.2ms
# Speed: 2.5ms preprocess, 16.2ms inference, 48.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2437.9      481.16      2811.5      822.18           7]
# [     2969.7      801.11      3491.3      1205.3           6]
#
# 0: 384x640 2 cars, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2447.9      487.47      2853.1      831.25           7]
# [     3010.9      811.71      3534.2      1218.9           6]
#
# 0: 384x640 3 cars, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2486.6      495.81      2907.8      836.19           7]
# [     3062.6      825.28      3586.8      1237.4           6]
#
# 0: 384x640 3 cars, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2522.8      505.16      2955.9      844.09           7]
# [     3108.2       839.8      3635.6      1254.6           6]
#
# 0: 384x640 3 cars, 16.6ms
# Speed: 2.5ms preprocess, 16.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2557.3      511.65      3000.1      850.21           7]
# [     3155.3      852.02      3682.9      1264.7           6]
#
# 0: 384x640 3 cars, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2601.1      518.55      3051.4      856.86           7]
# [     3204.9      867.39        3735      1279.9           6]
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2393.9      611.01      2671.6      980.89           8]
# [     2638.4      524.21      3094.4      863.76           7]
# [     3250.4      877.87        3782      1290.7           6]
#
# 0: 384x640 3 cars, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2399.4      616.41      2711.7      994.85           8]
# [     2676.3      531.54      3133.3      871.27           7]
# [     3297.8      887.28      3832.8      1302.3           6]
#
# 0: 384x640 3 cars, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2401.7      622.96      2756.4      1009.9           8]
# [     2724.1      536.19      3183.3      877.02           7]
# [     3340.9      895.96      3864.6      1312.6           6]
#
# 0: 384x640 3 cars, 16.9ms
# Speed: 2.3ms preprocess, 16.9ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2403.2      631.43      2793.5        1020           8]
# [     2765.4         543      3225.1      884.22           7]
# [     3375.9      906.55        3878      1325.4           6]
#
# 0: 384x640 3 cars, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2403.2      641.14      2831.5      1034.1           8]
# [     2802.9      550.62      3265.8      891.98           7]
# [       3416       917.8      3889.4      1338.6           6]
#
# 0: 384x640 3 cars, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2426.6      648.81      2885.1      1047.9           8]
# [       2851      559.35      3313.8      900.44           7]
# [     3458.7      931.59      3896.7      1354.2           6]
#
# 0: 384x640 4 cars, 16.3ms
# Speed: 2.2ms preprocess, 16.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2451.7      657.84      2932.3      1060.1           8]
# [     2887.1       567.5      3354.1      910.15           7]
# [     3501.9      947.87      3900.7      1371.8           6]
#
# 0: 384x640 5 cars, 17.7ms
# Speed: 2.4ms preprocess, 17.7ms inference, 46.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2483.6      667.83      2977.5      1069.3           8]
# [     2924.8      574.79      3395.2      918.33           7]
# [     3544.7      960.94        3902      1386.5           6]
#
# 0: 384x640 5 cars, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 44.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2527.2      682.23      3031.4      1081.9           8]
# [     2968.4      582.72      3442.4      928.24           7]
# [     3595.3      976.86      3905.6      1401.9           6]
#
# 0: 384x640 5 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
# [       2567      688.87      3078.4      1088.7           8]
# [     3011.4      590.11        3487      938.26           7]
# [     3644.1      990.47      3906.9      1415.6           6]
#
# 0: 384x640 5 cars, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 46.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2383.3      593.19      2620.9       962.7           9]
# [     2606.2      695.48      3122.4      1097.6           8]
# [     3050.9      598.53      3525.1      947.75           7]
# [     3690.6      1016.1      3905.9      1441.4           6]
#
# 0: 384x640 4 cars, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2385.7       590.6      2659.8      984.37           9]
# [     2650.8      705.07      3172.2      1110.3           8]
# [     3097.5      608.02      3574.2      958.28           7]
#
# 0: 384x640 4 cars, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 16.9ms postprocess per image at shape (1, 3, 384, 640)
# [       2395      589.18      2698.5      995.46           9]
# [     2693.8      712.43      3217.8      1121.2           8]
# [     3136.9      614.74      3614.1      965.86           7]
#
# 0: 384x640 4 cars, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2507.9      515.11      2903.2      772.98          10]
# [     2395.8      592.13      2733.3      1009.4           9]
# [     2734.9      721.27      3260.9      1130.4           8]
# [     3173.3      620.51      3653.7       974.8           7]
#
# 0: 384x640 4 cars, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2547.8      532.42      2965.3      816.48          10]
# [     2404.1       598.6      2781.6        1024           9]
# [     2783.7      733.23      3313.1        1143           8]
# [     3220.2      626.96      3700.9      981.93           7]
#
# 0: 384x640 4 cars, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2587.4      531.09      3006.3      809.49          10]
# [     2421.7      606.12      2826.4      1037.2           9]
# [     2824.9      747.35      3358.1      1155.2           8]
# [     3260.8      634.65      3743.7      992.61           7]
#
# 0: 384x640 4 cars, 1 truck, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2411.9      611.63      2863.1      1051.4           9]
# [     2867.6      758.18      3402.5      1166.7           8]
# [     3300.4      641.63      3783.4      1001.9           7]
#
# 0: 384x640 4 cars, 1 truck, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# [       2443         622      2918.1        1063           9]
# [     2916.6      769.08        3456        1178           8]
# [     3347.1      650.96      3830.1        1012           7]
#
# 0: 384x640 4 cars, 1 truck, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2471.1      631.08      2966.4      1075.2           9]
# [     2961.3      778.44      3501.8      1188.8           8]
# [     3377.7       658.6      3856.5      1019.7           7]
#
# 0: 384x640 5 cars, 1 truck, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 53.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2748.2      571.07        3183      871.41          10]
# [     2507.5      640.38      3014.3      1083.5           9]
# [       3006      790.46      3551.6      1202.8           8]
# [     3410.9      664.98      3872.9      1024.5           7]
#
# 0: 384x640 5 cars, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 39.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2787.1      577.06      3231.8      889.32          10]
# [     2552.2      652.31      3069.5      1094.4           9]
# [     3055.6      800.29      3604.4      1217.8           8]
# [     3445.5      676.72      3882.8        1040           7]
#
# 0: 384x640 6 cars, 17.0ms
# Speed: 2.2ms preprocess, 17.0ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2828.1       578.3      3273.6      895.47          10]
# [     2592.4      664.44      3115.7      1106.3           9]
# [     3101.5      810.86      3653.5      1232.2           8]
# [       3483      685.24      3889.6      1049.1           7]
#
# 0: 384x640 5 cars, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2865.4      583.12        3316      905.92          10]
# [     2628.9      673.75      3157.5      1116.1           9]
# [     3146.2      822.91      3699.6      1246.6           8]
# [     3517.1       696.5      3892.3      1062.3           7]
#
# 0: 384x640 5 cars, 17.5ms
# Speed: 2.2ms preprocess, 17.5ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2390.6      624.68      2657.1      985.26          11]
# [     2910.1      593.36      3364.3      927.85          10]
# [     2675.6      683.25      3209.2      1125.9           9]
# [     3198.8      838.64      3750.6      1259.8           8]
# [     3558.9      708.43      3896.7      1074.1           7]
#
# 0: 384x640 5 cars, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2393.1      629.49      2686.6      995.35          11]
# [     2947.3      596.89      3407.3      940.33          10]
# [       2717      690.83      3253.9      1135.6           9]
# [     3244.9      854.34        3799      1273.3           8]
#
# 0: 384x640 5 cars, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2399.6      633.56      2721.1      1003.2          11]
# [     2986.7      601.37      3447.8      947.75          10]
# [     2757.5       697.3      3298.7      1145.7           9]
# [       3289      867.95        3839      1285.7           8]
#
# 0: 384x640 4 cars, 17.4ms
# Speed: 2.1ms preprocess, 17.4ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2401.1      642.25        2759      1015.3          11]
# [     3052.1      610.12      3503.8      953.99          10]
# [     2801.1      709.48      3345.9      1158.9           9]
# [     3334.4      878.46      3868.9        1296           8]
#
# 0: 384x640 4 cars, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2399.9      650.03        2793        1027          11]
# [     2841.5      719.14      3387.2      1166.9           9]
# [     3375.6      885.66      3885.5      1304.5           8]
#
# 0: 384x640 4 cars, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2410.7      656.93      2832.5      1033.4          11]
# [     2880.7      728.43      3428.2      1176.2           9]
# [     3415.9      894.34      3893.8      1313.4           8]
#
# 0: 384x640 4 cars, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2415.4      669.59        2873      1047.5          11]
# [       2930      739.56      3480.8      1191.2           9]
# [     3462.1      910.57      3900.5      1331.8           8]
#
# 0: 384x640 4 cars, 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2441.6      682.14      2920.2      1057.1          11]
# [     3204.3      635.84      3673.3      995.56          10]
# [     2970.4      749.22      3522.9        1204           9]
# [     3506.1      923.82      3902.8      1346.7           8]
#
# 0: 384x640 4 cars, 17.4ms
# Speed: 2.2ms preprocess, 17.4ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2468.5      692.08      2965.6      1068.8          11]
# [     3246.1      645.44      3715.3        1005          10]
# [     3011.2      759.24      3565.8      1216.9           9]
# [     3550.7      932.31      3904.5      1357.9           8]
#
# 0: 384x640 4 cars, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2507.9      701.59      3015.2      1079.4          11]
# [     3288.4      654.48      3762.8        1015          10]
# [     3058.9      772.37      3617.8      1233.5           9]
# [     3605.1      948.79      3908.4      1374.9           8]
#
# 0: 384x640 4 cars, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2541.8      709.69      3059.8      1088.2          11]
# [     3326.6      662.44      3804.9      1024.2          10]
# [     3098.1      784.57      3660.9      1248.3           9]
# [       3653      958.06      3907.8        1386           8]
#
# 0: 384x640 4 cars, 17.6ms
# Speed: 2.1ms preprocess, 17.6ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2578.4      718.01      3100.9      1097.5          11]
# [       3363      670.03      3843.2      1036.2          10]
# [     3137.8      793.85      3704.1      1258.4           9]
#
# 0: 384x640 3 cars, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2621.6      728.43      3150.2      1108.9          11]
# [       3400       675.4      3866.4      1042.9          10]
# [     3184.2      807.77      3755.7      1270.2           9]
#
# 0: 384x640 3 cars, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2661.5      737.88      3192.4      1118.3          11]
# [     3433.1      668.21      3879.6      1014.8          10]
# [     3225.5      821.08      3799.9      1282.9           9]
#
# 0: 384x640 4 cars, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2698.6      747.06      3231.4      1126.8          11]
# [     3268.3      831.27        3845      1293.7           9]
#
# 0: 384x640 3 cars, 1 truck, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 51.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2741.5       759.4      3277.4      1140.2          11]
# [     3307.8      840.45      3870.1      1304.2           9]
#
# 0: 384x640 2 cars, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2781.9      771.15      3320.9        1154          11]
# [     3343.5      849.56        3883      1314.9           9]
#
# 0: 384x640 2 cars, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2822.2      780.01      3363.7      1164.7          11]
# [     3377.2      859.84      3889.8      1327.8           9]
#
# 0: 384x640 2 cars, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2867.7      790.95      3411.4      1178.2          11]
# [     3420.2      871.22        3897      1340.3           9]
#
# 0: 384x640 2 cars, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2905.1      799.68      3454.2      1189.9          11]
# [     3459.8      881.26      3899.5      1352.9           9]
#
# 0: 384x640 2 cars, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2944.1      806.83      3496.1      1200.9          11]
# [     3501.3      895.51      3901.1      1368.2           9]
#
# 0: 384x640 2 cars, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2989.2      818.39      3545.2      1217.2          11]
# [     3546.6      903.13      3903.1      1379.5           9]
#
# 0: 384x640 2 cars, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
# [       3030      827.23      3588.7      1230.7          11]
# [     3588.8      920.12      3902.8      1396.4           9]
#
# 0: 384x640 2 cars, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 53.3ms postprocess per image at shape (1, 3, 384, 640)
# [     3070.7      840.23        3633      1246.4          11]
# [     3631.4      932.39      3902.1      1413.9           9]
#
# 0: 384x640 2 cars, 15.6ms
# Speed: 2.3ms preprocess, 15.6ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# [     3118.3       855.2      3683.7      1260.6          11]
# [     3683.7       959.1      3904.8        1437           9]
#
# 0: 384x640 1 car, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 193.2ms postprocess per image at shape (1, 3, 384, 640)
# [     3159.9      867.37      3729.1      1271.2          11]
#
# 0: 384x640 1 car, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 51.2ms postprocess per image at shape (1, 3, 384, 640)
# [     3196.5      878.85        3770        1282          11]
#
# 0: 384x640 1 car, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
# [     3245.9      888.39      3823.1      1293.3          11]
#
# 0: 384x640 1 car, 17.0ms
# Speed: 2.2ms preprocess, 17.0ms inference, 55.3ms postprocess per image at shape (1, 3, 384, 640)
# [     3283.4      896.73      3856.5      1304.5          11]
#
# 0: 384x640 1 car, 1 tv, 17.4ms
# Speed: 2.1ms preprocess, 17.4ms inference, 58.5ms postprocess per image at shape (1, 3, 384, 640)
# [     3317.7      901.83      3875.2      1311.4          11]
#
# 0: 384x640 1 car, 1 tv, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 57.2ms postprocess per image at shape (1, 3, 384, 640)
# [     3357.5      913.73      3887.5      1324.8          11]
#
# 0: 384x640 1 car, 1 tv, 16.0ms
# Speed: 2.4ms preprocess, 16.0ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
# [     3398.7      927.54      3894.9      1340.9          11]
#
# 0: 384x640 1 car, 1 tv, 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# [     3438.2      938.92      3898.1      1351.9          11]
#
# 0: 384x640 1 car, 1 tv, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 56.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 tv, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 15.4ms
# Speed: 2.2ms preprocess, 15.4ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 12.9ms
# Speed: 2.2ms preprocess, 12.9ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 57.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.0ms
# Speed: 2.3ms preprocess, 17.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 12.6ms
# Speed: 2.2ms preprocess, 12.6ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.1ms
# Speed: 2.7ms preprocess, 16.1ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2440.8      505.03      2749.7      821.07          12]
#
# 0: 384x640 1 car, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2446.8      509.28      2796.4      831.15          12]
#
# 0: 384x640 1 car, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2460.9      515.64      2846.3      841.77          12]
#
# 0: 384x640 1 car, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2500.8      524.35      2909.4      852.99          12]
#
# 0: 384x640 1 car, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
# [     2541.8      531.79      2966.5      862.22          12]
#
# 0: 384x640 1 car, 16.8ms
# Speed: 1.9ms preprocess, 16.8ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2586.2      540.62      3018.7      871.65          12]
#
# 0: 384x640 1 car, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2641.4      549.84      3079.7      880.58          12]
#
# 0: 384x640 1 car, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2689.1      559.93      3132.2      889.94          12]
#
# 0: 384x640 1 car, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2735.8      570.03      3182.2      898.41          12]
#
# 0: 384x640 1 car, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2793.7      580.19        3245      910.46          12]
#
# 0: 384x640 1 car, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2842.6      589.24      3296.3      921.01          12]
#
# 0: 384x640 1 car, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
# [       2891      598.46      3347.7      931.71          12]
#
# 0: 384x640 1 car, 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2948.9      609.45      3407.8       944.7          12]
#
# 0: 384x640 1 car, 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2999.4      619.28        3461      956.41          12]
#
# 0: 384x640 1 car, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
# [     3049.2      627.04      3513.4      965.32          12]
#
# 0: 384x640 1 car, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# [     3107.4      636.96      3575.3      977.46          12]
#
# 0: 384x640 1 car, 17.2ms
# Speed: 2.8ms preprocess, 17.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
# [     3160.3      647.61      3631.3      988.93          12]
#
# 0: 384x640 1 car, 16.3ms
# Speed: 2.3ms preprocess, 16.3ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# [     3210.1      656.85      3683.6       999.2          12]
#
# 0: 384x640 2 cars, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 53.8ms postprocess per image at shape (1, 3, 384, 640)
# [     3269.5      670.11      3744.7      1013.6          12]
#
# 0: 384x640 2 cars, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 18.9ms postprocess per image at shape (1, 3, 384, 640)
# [     3321.2      679.21      3798.1      1025.5          12]
#
# 0: 384x640 2 cars, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# [     3370.3       688.5      3846.3      1036.5          12]
#
# 0: 384x640 2 cars, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# [     3418.8      699.98      3875.1      1049.7          12]
#
# 0: 384x640 2 cars, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2431.9      494.36      2737.4      827.31          13]
# [     3463.5      711.67      3890.4      1061.1          12]
#
# 0: 384x640 2 cars, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2436.8       499.5      2782.6      836.09          13]
# [       3507      722.65      3898.4      1071.9          12]
#
# 0: 384x640 2 cars, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2459.4      507.59      2843.4      850.03          13]
# [     3561.3      736.91      3907.1      1086.2          12]
#
# 0: 384x640 2 cars, 15.9ms
# Speed: 2.2ms preprocess, 15.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2492.9      515.08      2897.4       857.7          13]
# [     3610.4      748.23      3909.5      1097.4          12]
#
# 0: 384x640 2 cars, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2533.7      524.08      2951.2      865.76          13]
# [     3660.3      758.95      3910.3      1107.5          12]
#
# 0: 384x640 1 car, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2581.1      533.49      3006.9      874.07          13]
#
# 0: 384x640 1 car, 17.3ms
# Speed: 2.4ms preprocess, 17.3ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2628.8         542      3060.9      882.83          13]
#
# 0: 384x640 1 car, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2673.8      550.96        3110      892.31          13]
#
# 0: 384x640 1 car, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2728.4      562.09      3168.1      900.73          13]
#
# 0: 384x640 1 car, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2776.8      571.86      3221.1      912.23          13]
#
# 0: 384x640 1 car, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2823.9      580.74      3270.4      921.25          13]
#
# 0: 384x640 1 car, 16.2ms
# Speed: 2.5ms preprocess, 16.2ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2877.8      590.55      3326.9      933.38          13]
#
# 0: 384x640 1 car, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2926.3      599.42      3378.7      944.65          13]
#
# 0: 384x640 1 car, 17.4ms
# Speed: 2.2ms preprocess, 17.4ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2972.7      609.43      3426.8      956.06          13]
#
# 0: 384x640 1 car, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
# [     3031.3      618.82      3487.5       966.6          13]
#
# 0: 384x640 1 car, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
# [     3082.6       628.1      3540.4      977.99          13]
#
# ...
# [     3312.2      638.49      3768.8      1017.1          58]
# [     3688.6      956.37      3897.6      1448.6          57]
#
# 0: 384x640 3 cars, 18.9ms
# Speed: 2.5ms preprocess, 18.9ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# [       2396      529.12      2630.6      971.93          60]
# [     3007.5      797.01        3569      1204.2          59]
# [       3358      646.67      3818.4      1028.6          58]
#
# 0: 384x640 3 cars, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
# [       2400       519.2      2668.1      985.27          60]
# [     3048.4      808.29      3613.7      1219.5          59]
# [     3397.5      655.18      3854.1      1039.4          58]
#
# 0: 384x640 3 cars, 17.5ms
# Speed: 2.5ms preprocess, 17.5ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2406.2      523.88      2704.7      998.71          60]
# [     3087.4       817.3      3656.9      1233.1          59]
# [     3431.7      660.99      3872.5      1046.9          58]
#
# 0: 384x640 3 cars, 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2409.4      524.92      2748.8      1013.4          60]
# [       3134       828.1      3705.7      1247.8          59]
#
# 0: 384x640 3 cars, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2402.4      529.46      2787.2      1027.7          60]
# [     3175.6      842.12      3750.6      1261.1          59]
#
# 0: 384x640 3 cars, 17.0ms
# Speed: 2.4ms preprocess, 17.0ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2404.2      539.69        2827      1037.9          60]
# [     3215.1      854.58      3792.3      1272.1          59]
#
# 0: 384x640 3 cars, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# [       2416      553.66      2876.2      1050.2          60]
# [     3263.8      867.97      3841.6      1284.5          59]
#
# 0: 384x640 3 cars, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2419.3      562.33      2916.6      1060.3          60]
# [     3299.7      876.09      3866.4      1293.4          59]
#
# 0: 384x640 2 cars, 17.8ms
# Speed: 2.1ms preprocess, 17.8ms inference, 22.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2437.9      571.03      2962.5      1070.2          60]
# [     3334.1      884.77      3881.2      1301.5          59]
#
# 0: 384x640 2 cars, 16.3ms
# Speed: 1.8ms preprocess, 16.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2476.3      576.66      3017.7      1077.7          60]
# [     3371.8      896.34      3890.2      1314.6          59]
#
# 0: 384x640 2 cars, 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2510.8      584.73      3064.9      1087.4          60]
# [       3411       906.1      3895.7      1327.2          59]
#
# 0: 384x640 2 cars, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2545.6      594.94      3109.1      1096.6          60]
# [     3447.9      917.31      3897.6      1340.1          59]
#
# 0: 384x640 2 cars, 18.8ms
# Speed: 2.1ms preprocess, 18.8ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2590.7       602.8      3162.2      1108.8          60]
# [     3495.4      932.52      3902.3      1357.6          59]
#
# 0: 384x640 2 cars, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
# [     2629.1      610.87      3206.2        1119          60]
# [     3537.1      946.34      3902.3      1372.4          59]
#
# 0: 384x640 2 cars, 16.5ms
# Speed: 2.9ms preprocess, 16.5ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# [       2668      617.38      3249.5      1127.4          60]
# [     3577.4      956.31      3901.3      1383.7          59]
#
# 0: 384x640 2 cars, 16.2ms
# Speed: 2.4ms preprocess, 16.2ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2713.4      626.92      3299.2      1139.4          60]
# [     3625.5      969.89      3903.8      1402.2          59]
#
# 0: 384x640 2 cars, 18.1ms
# Speed: 2.3ms preprocess, 18.1ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# [     2755.4      638.96        3344      1153.4          60]
# [     3672.7      996.23      3903.9      1425.2          59]
#
# 0: 384x640 1 car, 18.0ms
# Speed: 2.9ms preprocess, 18.0ms inference, 21.7ms postprocess per image at shape (1, 3, 384, 640)
# [     2795.7      651.35      3388.6      1165.4          60]
#
# 0: 384x640 1 car, 18.7ms
# Speed: 2.2ms preprocess, 18.7ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# [     2840.2      663.23      3438.1      1177.9          60]
#
# 0: 384x640 1 car, 19.4ms
# Speed: 2.1ms preprocess, 19.4ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2886.2      676.43      3486.8      1189.7          60]
#
# 0: 384x640 1 car, 20.8ms
# Speed: 6.5ms preprocess, 20.8ms inference, 21.1ms postprocess per image at shape (1, 3, 384, 640)
# [       2924      683.83      3528.2      1199.7          60]
#
# 0: 384x640 1 car, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2972.5      692.85      3580.4        1217          60]
#
# 0: 384x640 1 car, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# [     3015.4       698.6      3625.5      1226.4          60]
#
# 0: 384x640 1 car, 16.3ms
# Speed: 2.7ms preprocess, 16.3ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# [       3058      706.93      3669.2      1238.9          60]
#
# 0: 384x640 1 car, 17.9ms
# Speed: 2.4ms preprocess, 17.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# [     3107.6      736.69      3722.3      1262.2          60]
#
# 0: 384x640 1 car, 20.6ms
# Speed: 2.4ms preprocess, 20.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# [       3147      748.35      3766.3      1272.6          60]
#
# 0: 384x640 1 car, 18.5ms
# Speed: 2.2ms preprocess, 18.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# [     3186.2      756.08        3807      1280.4          60]
#
# 0: 384x640 1 car, 17.6ms
# Speed: 3.9ms preprocess, 17.6ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
# [     3229.4      765.56      3848.9      1291.1          60]
#
# 0: 384x640 1 car, 17.4ms
# Speed: 2.4ms preprocess, 17.4ms inference, 21.1ms postprocess per image at shape (1, 3, 384, 640)
# [     3267.3      770.83        3872      1298.7          60]
#
# 0: 384x640 2 cars, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
# [     3302.4      777.23      3884.8      1306.9          60]
#
# 0: 384x640 2 cars, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# [     3344.7      783.61      3895.3      1319.1          60]
#
# 0: 384x640 2 cars, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
# [     3385.1      792.43      3899.9      1331.8          60]
#
# 0: 384x640 2 cars, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# [       3423       803.8      3900.8      1346.8          60]
#
# 0: 384x640 2 cars, 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 18.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2388.3      631.06      2669.7      996.06          61]
# [     3468.5      819.56      3903.6      1364.6          60]
#
# 0: 384x640 2 cars, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2396.6      635.32        2704      1004.4          61]
# [       3512      832.84      3904.4      1378.4          60]
#
# 0: 384x640 2 cars, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# [     2399.9      639.92      2739.4      1017.7          61]
# [     3552.9      845.13      3902.9      1393.9          60]
#
# 0: 384x640 2 cars, 17.5ms
# Speed: 2.2ms preprocess, 17.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
# [     2402.3      648.79      2780.8      1031.3          61]
#
# 0: 384x640 1 car, 1 fire hydrant, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# [     2401.7      657.28      2816.5      1043.2          61]
#
# 0: 384x640 1 car, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# [     2418.5      667.73      2857.9      1051.6          61]
#
# 0: 384x640 1 car, 17.8ms
# Speed: 2.1ms preprocess, 17.8ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
# [     2439.6      678.81      2902.4      1060.9          61]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 8
#       4 results = model(img_region, stream=True)
#       6 detection=np.empty((0,5))
# ----> 8 for r in results:
#       9     boxes = r.boxes
#      10     for box in boxes:
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/ultralytics/nn/autobackend.py:456, in AutoBackend.forward(self, im, augment, visualize, embed)
#     454 # PyTorch
#     455 if self.pt or self.nn_module:
# --> 456     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     458 # TorchScript
#     459 elif self.jit:
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:106, in BaseModel.forward(self, x, *args, **kwargs)
#     104 if isinstance(x, dict):  # for cases of training and validating while training.
#     105     return self.loss(x, *args, **kwargs)
# --> 106 return self.predict(x, *args, **kwargs)
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:124, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     122 if augment:
#     123     return self._predict_augment(x)
# --> 124 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:145, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     143 if profile:
#     144     self._profile_one_layer(m, x, dt)
# --> 145 x = m(x)  # run
#     146 y.append(x if m.i in self.save else None)  # save output
#     147 if visualize:
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/torch/nn/modules/upsampling.py:158, in Upsample.forward(self, input)
#     157 def forward(self, input: Tensor) -> Tensor:
# --> 158     return F.interpolate(input, self.size, self.scale_factor, self.mode, self.align_corners,
#     159                          recompute_scale_factor=self.recompute_scale_factor)
#
# File ~/Desktop/yolo/yoloenv/lib/python3.12/site-packages/torch/nn/functional.py:4050, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4048     return torch._C._nn.upsample_nearest1d(input, output_size, scale_factors)
#    4049 if input.dim() == 4 and mode == "nearest":
# -> 4050     return torch._C._nn.upsample_nearest2d(input, output_size, scale_factors)
#    4051 if input.dim() == 5 and mode == "nearest":
#    4052     return torch._C._nn.upsample_nearest3d(input, output_size, scale_factors)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import torch

print(torch.__version__)
# Out:
# 2.4.1

# %%
import torch

if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("MPS device is available.")
else:
    device = torch.device("cpu")
    print("MPS device is not available, using CPU.")
# Out:
# MPS device is available.
